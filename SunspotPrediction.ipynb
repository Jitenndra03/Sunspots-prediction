# %% [markdown]
# <a href="https://colab.research.google.com/github/Jitenndra03/Sunspots-prediction/blob/main/SunspotPrediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Diving into dataset

# %%
# Importing necessary libraries

'''Visualization'''
import matplotlib.pyplot as plt
import seaborn as sns

'''Data Handling and Linear Algebra'''
import pandas as pd
import numpy as np

'''Manipulating data and Model Building'''
import tensorflow as tf

'''Ignore Warnings'''
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("/content/Sunspots.csv")
data.head()
# Out:
#    Unnamed: 0        Date  Monthly Mean Total Sunspot Number
# 0           0  1749-01-31                               96.7
# 1           1  1749-02-28                              104.3
# 2           2  1749-03-31                              116.7
# 3           3  1749-04-30                               92.8
# 4           4  1749-05-31                              141.7

# %%
data.tail()
# Out:
#       Unnamed: 0        Date  Monthly Mean Total Sunspot Number
# 3260        3260  2020-09-30                                0.6
# 3261        3261  2020-10-31                               14.4
# 3262        3262  2020-11-30                               34.0
# 3263        3263  2020-12-31                               21.8
# 3264        3264  2021-01-31                               10.4

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3265 entries, 0 to 3264
# Data columns (total 3 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Unnamed: 0                         3265 non-null   int64
#  1   Date                               3265 non-null   object
#  2   Monthly Mean Total Sunspot Number  3265 non-null   float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 76.7+ KB

# %%
# Last coloumn ----> Sunspots data
sunspots = data.iloc[:,-1]
sunspots.values
# Out:
# array([ 96.7, 104.3, 116.7, ...,  34. ,  21.8,  10.4])

# %%
# Visualize the data
plt.figure(figsize=(28,10))
plt.plot(sunspots)
plt.ylabel(data.columns[-1], fontsize = 12, color = 'm')
plt.xlabel("Months from Jan 1749 to Jan 2021", fontsize = 12, color = 'm')
plt.title("Visulaize the data", fontsize = 18, color = 'r', weight = 'bold')
plt.show()

# %%
# Highlighting the above points in our visualization
'''Approx 11 years cycle ---> approx 132 months cycle'''
plt.figure(figsize=(28,6))
plt.plot(sunspots) # The whole data
plt.plot(sunspots[:72]) # Data from 1749, actual cycle starts from 1755 ---> 6 years means 72 months
plt.plot(sunspots[72:72+132]) # Showing the first cycle
plt.plot(sunspots[-13:]) # Displaying the current cycle
plt.ylabel(data.columns[-1], fontsize = 12, color = 'm')
plt.xlabel("Months from Jan 1749 to Jan 2021", fontsize = 12, color = 'm')
plt.title("Understanding the Sunspots data", fontsize = 18, color = 'r', weight = 'bold')
plt.legend(["Full data", "Before 1755 - The first cycle", "The first cycle", "After 2019 - The current cycle"], fontsize = 12)
plt.show()

# %%
# Some changes for a better visualization of solar cycles

'''Collect all the years from 1755 to 2019 and use it as xticklabels'''
years = []
start = 1755
for i in range(0, len(data.iloc[:, -1][72:]), 132):
  years.append(start)
  start += 11

plt.figure(figsize=(28, 6))
plt.plot(sunspots[72:])
plt.title("visulaize Solar cycle 1 till solar cycle 24", weight = 'bold', color = 'r', fontsize = 18)
plt.xlim(72, 3265-12)
plt.xticks(range(72, len(sunspots), 132))
plt.gca().set_xticklabels(years)
plt.show()

# %%
# Visualise the variation in the data distribution along with the outliers in the time series data
plt.figure(figsize = (15,6))
plt.subplot(2, 1, 1)
sns.histplot(sunspots, kde=True) # Changed to histplot for better distribution visualization
plt.title("Variation in the data distribution", fontsize = 15, color = 'r', weight = 'bold')
plt.subplot(2, 1, 2)
sns.boxplot(x=sunspots) # Specify sunspots on the x-axis for horizontal orientation
plt.title("Boxplot of data", fontsize = 15, color = 'r', weight = 'bold')
plt.tight_layout()
plt.show()

# %%
#Helper function: Training data generation
def windowed_dataset(series, window_size, batch_size, shuffle_buffer):
    series = series[:, np.newaxis]                                # Adding new dimension to the series array in the position where np.newaxis is written
    ds = tf.data.Dataset.from_tensor_slices(series)               # In order to use window of tensorflow convert numpy array to tensor
    ds = ds.window(window_size + 1, shift=1, drop_remainder=True) # Creating window for generating sequence (yet not seperating it with the future values) - LSTM
    ds = ds.flat_map(lambda w: w.batch(window_size + 1))          # Flatten a dataset of batches into a dataset of their elements
    ds = ds.shuffle(shuffle_buffer)                               # To reduce the variance and making sure that the model remain general and less overfits
    ds = ds.map(lambda w: (w[:-1], w[-1]))                        # In a window, last value is the future value that our model needs to learn and predict while testing it
    return ds.batch(batch_size).prefetch(1)                       # Prefetch one batch of data and make sure that there is always one ready

# %% [markdown]
# ## Breaking down the above function to understand what exactly is happening!

# %%
'''For example take the first 10 examples from the sunspots series'''
dum_series = sunspots[:10].values  # Numpy array
dum_series, dum_series.shape       # Display array and its shape
# Out:
# (array([ 96.7, 104.3, 116.7,  92.8, 141.7, 139.2, 158. , 110.5, 126.5,
#         125.8]),
#  (10,))

# %%
'''Adding a new dimension in the place where np.axis is used'''
dum_series=dum_series[:, np.newaxis]   # Shape now should be 10x1
dum_series, dum_series.shape           # Check
# Out:
# (array([[[ 96.7]],
#
#         [[104.3]],
#
#         [[116.7]],
#
#         [[ 92.8]],
#
#         [[141.7]],
#
#         [[139.2]],
#
#         [[158. ]],
#
#         [[110.5]],
#
#         [[126.5]],
#
#         [[125.8]]]),
#  (10, 1, 1))

# %%
'''To use the window method of tensorflow to generate the sequence for LSTM we need to generate tensor from the numpy array'''
ds = tf.data.Dataset.from_tensor_slices(dum_series)  # Window method of tensorflow won't work on numpy array

# Display the content of the above dataset
for i in ds:
    for val in i:
        print(val)
# Out:
# tf.Tensor([96.7], shape=(1,), dtype=float64)
# tf.Tensor([104.3], shape=(1,), dtype=float64)
# tf.Tensor([116.7], shape=(1,), dtype=float64)
# tf.Tensor([92.8], shape=(1,), dtype=float64)
# tf.Tensor([141.7], shape=(1,), dtype=float64)
# tf.Tensor([139.2], shape=(1,), dtype=float64)
# tf.Tensor([158.], shape=(1,), dtype=float64)
# tf.Tensor([110.5], shape=(1,), dtype=float64)
# tf.Tensor([126.5], shape=(1,), dtype=float64)
# tf.Tensor([125.8], shape=(1,), dtype=float64)

# %%
'''Generate sequence of length 3 ---> Hence prev 3 values will be used to train our model to learn and predict the 4th value'''
window_size = 3                                               # Sequence Length
ds = ds.window(window_size + 1, shift=1, drop_remainder=True) # Drop remainder if True ensures the same shape of the tensor

# Display the changes
for i in ds:
    for val in i:
        print(val)
# Out:
# tf.Tensor([[96.7]], shape=(1, 1), dtype=float64)
# tf.Tensor([[104.3]], shape=(1, 1), dtype=float64)
# tf.Tensor([[116.7]], shape=(1, 1), dtype=float64)
# tf.Tensor([[92.8]], shape=(1, 1), dtype=float64)
# tf.Tensor([[104.3]], shape=(1, 1), dtype=float64)
# tf.Tensor([[116.7]], shape=(1, 1), dtype=float64)
# tf.Tensor([[92.8]], shape=(1, 1), dtype=float64)
# tf.Tensor([[141.7]], shape=(1, 1), dtype=float64)
# tf.Tensor([[116.7]], shape=(1, 1), dtype=float64)
# tf.Tensor([[92.8]], shape=(1, 1), dtype=float64)
# tf.Tensor([[141.7]], shape=(1, 1), dtype=float64)
# tf.Tensor([[139.2]], shape=(1, 1), dtype=float64)
# tf.Tensor([[92.8]], shape=(1, 1), dtype=float64)
# tf.Tensor([[141.7]], shape=(1, 1), dtype=float64)
# tf.Tensor([[139.2]], shape=(1, 1), dtype=float64)
# tf.Tensor([[158.]], shape=(1, 1), dtype=float64)
# tf.Tensor([[141.7]], shape=(1, 1), dtype=float64)
# tf.Tensor([[139.2]], shape=(1, 1), dtype=float64)
# tf.Tensor([[158.]], shape=(1, 1), dtype=float64)
# tf.Tensor([[110.5]], shape=(1, 1), dtype=float64)
# tf.Tensor([[139.2]], shape=(1, 1), dtype=float64)
# tf.Tensor([[158.]], shape=(1, 1), dtype=float64)
# tf.Tensor([[110.5]], shape=(1, 1), dtype=float64)
# tf.Tensor([[126.5]], shape=(1, 1), dtype=float64)
# tf.Tensor([[158.]], shape=(1, 1), dtype=float64)
# tf.Tensor([[110.5]], shape=(1, 1), dtype=float64)
# tf.Tensor([[126.5]], shape=(1, 1), dtype=float64)
# tf.Tensor([[125.8]], shape=(1, 1), dtype=float64)

# %%
'''Flatten the dataset and map the function given in method argument across the dataset'''
ds = ds.flat_map(lambda w: w.batch(window_size + 1)) # Batch of 4 is what we want for this example
ds = ds.map(lambda w: (w[:-1], w[-1]))               # Two different outputs we should get ---> Sequence of 3 and 1 label

# Display the change
for i in ds:
    for val in i:
        print(val)
# Out:
# tf.Tensor(
# [[[ 96.7]]
#
#  [[104.3]]
#
#  [[116.7]]], shape=(3, 1, 1), dtype=float64)
# tf.Tensor([[92.8]], shape=(1, 1), dtype=float64)
# tf.Tensor(
# [[[104.3]]
#
#  [[116.7]]
#
#  [[ 92.8]]], shape=(3, 1, 1), dtype=float64)
# tf.Tensor([[141.7]], shape=(1, 1), dtype=float64)
# tf.Tensor(
# [[[116.7]]
#
#  [[ 92.8]]
#
#  [[141.7]]], shape=(3, 1, 1), dtype=float64)
# tf.Tensor([[139.2]], shape=(1, 1), dtype=float64)
# tf.Tensor(
# [[[ 92.8]]
#
#  [[141.7]]
#
#  [[139.2]]], shape=(3, 1, 1), dtype=float64)
# tf.Tensor([[158.]], shape=(1, 1), dtype=float64)
# tf.Tensor(
# [[[141.7]]
#
#  [[139.2]]
#
#  [[158. ]]], shape=(3, 1, 1), dtype=float64)
# tf.Tensor([[110.5]], shape=(1, 1), dtype=float64)
# tf.Tensor(
# [[[139.2]]
#
#  [[158. ]]
#
#  [[110.5]]], shape=(3, 1, 1), dtype=float64)
# tf.Tensor([[126.5]], shape=(1, 1), dtype=float64)
# tf.Tensor(
# [[[158. ]]
#
#  [[110.5]]
#
#  [[126.5]]], shape=(3, 1, 1), dtype=float64)
# tf.Tensor([[125.8]], shape=(1, 1), dtype=float64)

# %%
'''Generate the final dataset for LSTM in shape of batch_size x sequence_length x #features and respective labels'''
ds = ds.batch(10).prefetch(1)  # sequence of length 3 for total of 10 examples means max_batch_size of 10 - 3 = 7 should be there
'''Shape of sequence data will be 7 x 3 x 1 and for labels it will be 7 x 1'''

# Display the final 3D Data
for i in ds:
    for val in i:
        print(val)
    print("\n")
# Out:
# tf.Tensor(
# [[[[ 96.7]]
#
#   [[104.3]]
#
#   [[116.7]]]
#
#
#  [[[104.3]]
#
#   [[116.7]]
#
#   [[ 92.8]]]
#
#
#  [[[116.7]]
#
#   [[ 92.8]]
#
#   [[141.7]]]
#
#
#  [[[ 92.8]]
#
#   [[141.7]]
#
#   [[139.2]]]
#
#
#  [[[141.7]]
#
#   [[139.2]]
#
#   [[158. ]]]
#
#
#  [[[139.2]]
#
#   [[158. ]]
#
#   [[110.5]]]
#
#
#  [[[158. ]]
#
#   [[110.5]]
#
#   [[126.5]]]], shape=(7, 3, 1, 1), dtype=float64)
# tf.Tensor(
# [[[ 92.8]]
#
#  [[141.7]]
#
#  [[139.2]]
#
#  [[158. ]]
#
#  [[110.5]]
#
#  [[126.5]]
#
#  [[125.8]]], shape=(7, 1, 1), dtype=float64)

# %%
# Forecast would work in the same way where we provide the sequence and the output will be predicted by the model
def model_forecast(model, series, window_size):
    ds = tf.data.Dataset.from_tensor_slices(series)
    ds = ds.window(window_size, shift=1, drop_remainder=True)
    ds = ds.flat_map(lambda w: w.batch(window_size))
    ds = ds.batch(batch_size).prefetch(1)
    forecast = model.predict(ds)  # To predict
    return forecast

# %%
# Preparing the data
series = data['Monthly Mean Total Sunspot Number'].values
time = data['Unnamed: 0'].values

# Splitting the data into train and test
split_time = int(len(series)*0.9)          # 90% of the original data is for training
time_train = time[:split_time]
x_train = series[:split_time]
time_valid = time[split_time:]
x_valid = series[split_time:]
print(f"There are {len(x_train)} training samples and {len(x_valid)} validation samples.")

# Parameters
delta = 1                      # Huber loss
window_size = 60               # For dataset
batch_size = 145               # For dataset
shuffle_buffer_size= 900       # Shuffling the dataset randomly
epochs = 100                   # For optimal learning rate
train_epochs = epochs + 100    # Training epochs
momentum_sgd = 0.9             # For optimizer
# Out:
# There are 2938 training samples and 327 validation samples.

# %%
# To avoid clutter from old models and layers (in case of re-running the notebook without reset and resestart)
tf.keras.backend.clear_session()

# To produce same sequence of results each time the code runs
tf.random.set_seed(42)
np.random.seed(42)

# Calling the window_dataset function to generate the training data
train_set = windowed_dataset(x_train, window_size, batch_size, shuffle_buffer_size)

# Building the model
model = tf.keras.models.Sequential([
  # Conv1D layers smoothens out the input time-series so we don't have to add the rolling mean or rolling standard deviation values in the input features
  tf.keras.layers.Conv1D(filters=132, kernel_size=4,strides=1, padding="causal", activation="relu",input_shape=[None, 1]),
  tf.keras.layers.LSTM(256, return_sequences=True), # Return sequence if set to true will return the outputs for each time step as explained above
  tf.keras.layers.LSTM(132, return_sequences=False),# Setting it as False will only output the last time step which will then be feeded into the fully connected layers
  tf.keras.layers.Dense(80, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 400)        # To push the values in the range of the original data after getting passed from different activations
])

# Display this model summary
model.summary()

# Using callbacks - Learning rate scheduler to find the optimal value to be used in the final model
lr_schedule = tf.keras.callbacks.LearningRateScheduler(lambda epoch: 1e-8 * 10**(epoch / 20), verbose = 0) # lr --> starting lr * 10^(0/20), starting lr * 10^(1/20), so on..

# Stochastic Gradient Desect as the optimizer
optimizer = tf.keras.optimizers.SGD(learning_rate=1e-8, momentum=momentum_sgd)
model.compile(loss=tf.keras.losses.Huber(delta),
              optimizer=optimizer,
              metrics=["mae"])
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, None, 132)      │           660 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, None, 256)      │       398,336 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 132)            │       205,392 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 80)             │        10,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │           810 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            11 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lambda (Lambda)                 │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 615,849 (2.35 MB)
#  Trainable params: 615,849 (2.35 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(train_set, epochs=epochs, callbacks=[lr_schedule]) # Track the history of training
# Out:
# Epoch 1/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 6s 31ms/step - loss: 52.9945 - mae: 53.4917 - learning_rate: 1.0000e-08
# Epoch 2/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 47.0779 - mae: 47.5768 - learning_rate: 1.1220e-08
# Epoch 3/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 44.6970 - mae: 45.1945 - learning_rate: 1.2589e-08
# Epoch 4/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 41.0593 - mae: 41.5566 - learning_rate: 1.4125e-08
# Epoch 5/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 36.5236 - mae: 37.0203 - learning_rate: 1.5849e-08
# Epoch 6/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 34.8179 - mae: 35.3155 - learning_rate: 1.7783e-08
# Epoch 7/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 32.9689 - mae: 33.4664 - learning_rate: 1.9953e-08
# Epoch 8/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 30.8859 - mae: 31.3823 - learning_rate: 2.2387e-08
# Epoch 9/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 29.2997 - mae: 29.7974 - learning_rate: 2.5119e-08
# Epoch 10/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 27.2425 - mae: 27.7391 - learning_rate: 2.8184e-08
# Epoch 11/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 26.4597 - mae: 26.9548 - learning_rate: 3.1623e-08
# Epoch 12/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 25.4756 - mae: 25.9719 - learning_rate: 3.5481e-08
# Epoch 13/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 25.3886 - mae: 25.8849 - learning_rate: 3.9811e-08
# Epoch 14/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 23.7007 - mae: 24.1959 - learning_rate: 4.4668e-08
# Epoch 15/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 22.4203 - mae: 22.9135 - learning_rate: 5.0119e-08
# Epoch 16/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 22.1443 - mae: 22.6374 - learning_rate: 5.6234e-08
# Epoch 17/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 22.6401 - mae: 23.1350 - learning_rate: 6.3096e-08
# Epoch 18/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 21.4170 - mae: 21.9127 - learning_rate: 7.0795e-08
# Epoch 19/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 22.6081 - mae: 23.1028 - learning_rate: 7.9433e-08
# Epoch 20/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 22.1287 - mae: 22.6245 - learning_rate: 8.9125e-08
# Epoch 21/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 20.6660 - mae: 21.1608 - learning_rate: 1.0000e-07
# Epoch 22/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 20.9356 - mae: 21.4278 - learning_rate: 1.1220e-07
# Epoch 23/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 21.2130 - mae: 21.7067 - learning_rate: 1.2589e-07
# Epoch 24/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 20.4276 - mae: 20.9203 - learning_rate: 1.4125e-07
# Epoch 25/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 20.2502 - mae: 20.7433 - learning_rate: 1.5849e-07
# Epoch 26/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 20.1300 - mae: 20.6241 - learning_rate: 1.7783e-07
# Epoch 27/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 19.2006 - mae: 19.6944 - learning_rate: 1.9953e-07
# Epoch 28/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 19.9417 - mae: 20.4348 - learning_rate: 2.2387e-07
# Epoch 29/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 19.5826 - mae: 20.0761 - learning_rate: 2.5119e-07
# Epoch 30/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 19.0167 - mae: 19.5103 - learning_rate: 2.8184e-07
# Epoch 31/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 18.9269 - mae: 19.4193 - learning_rate: 3.1623e-07
# Epoch 32/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 19.2164 - mae: 19.7068 - learning_rate: 3.5481e-07
# Epoch 33/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 18.7854 - mae: 19.2741 - learning_rate: 3.9811e-07
# Epoch 34/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 18.4140 - mae: 18.9035 - learning_rate: 4.4668e-07
# Epoch 35/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 18.1723 - mae: 18.6613 - learning_rate: 5.0119e-07
# Epoch 36/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 28ms/step - loss: 18.5117 - mae: 19.0006 - learning_rate: 5.6234e-07
# Epoch 37/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 18.2932 - mae: 18.7840 - learning_rate: 6.3096e-07
# Epoch 38/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.9159 - mae: 18.4064 - learning_rate: 7.0795e-07
# Epoch 39/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.7067 - mae: 18.1973 - learning_rate: 7.9433e-07
# Epoch 40/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.7692 - mae: 18.2591 - learning_rate: 8.9125e-07
# Epoch 41/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.7651 - mae: 18.2564 - learning_rate: 1.0000e-06
# Epoch 42/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.6109 - mae: 18.1011 - learning_rate: 1.1220e-06
# Epoch 43/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 17.4488 - mae: 17.9395 - learning_rate: 1.2589e-06
# Epoch 44/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.1696 - mae: 17.6600 - learning_rate: 1.4125e-06
# Epoch 45/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 18.7752 - mae: 19.2670 - learning_rate: 1.5849e-06
# Epoch 46/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 17.7259 - mae: 18.2174 - learning_rate: 1.7783e-06
# Epoch 47/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 17.0597 - mae: 17.5500 - learning_rate: 1.9953e-06
# Epoch 48/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 17.0412 - mae: 17.5313 - learning_rate: 2.2387e-06
# Epoch 49/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 16.8297 - mae: 17.3198 - learning_rate: 2.5119e-06
# Epoch 50/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.9249 - mae: 17.4153 - learning_rate: 2.8184e-06
# Epoch 51/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.6594 - mae: 18.1514 - learning_rate: 3.1623e-06
# Epoch 52/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.1153 - mae: 17.6048 - learning_rate: 3.5481e-06
# Epoch 53/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.7967 - mae: 18.2893 - learning_rate: 3.9811e-06
# Epoch 54/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.2383 - mae: 17.7295 - learning_rate: 4.4668e-06
# Epoch 55/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.6103 - mae: 17.1008 - learning_rate: 5.0119e-06
# Epoch 56/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.1393 - mae: 17.6284 - learning_rate: 5.6234e-06
# Epoch 57/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 17.2283 - mae: 17.7197 - learning_rate: 6.3096e-06
# Epoch 58/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.0899 - mae: 17.5796 - learning_rate: 7.0795e-06
# Epoch 59/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 32ms/step - loss: 18.1807 - mae: 18.6714 - learning_rate: 7.9433e-06
# Epoch 60/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 17.4889 - mae: 17.9812 - learning_rate: 8.9125e-06
# Epoch 61/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 18.3710 - mae: 18.8620 - learning_rate: 1.0000e-05
# Epoch 62/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.5840 - mae: 18.0763 - learning_rate: 1.1220e-05
# Epoch 63/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 18.4412 - mae: 18.9334 - learning_rate: 1.2589e-05
# Epoch 64/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 19.2730 - mae: 19.7667 - learning_rate: 1.4125e-05
# Epoch 65/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 19.7070 - mae: 20.2006 - learning_rate: 1.5849e-05
# Epoch 66/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 18.2838 - mae: 18.7752 - learning_rate: 1.7783e-05
# Epoch 67/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 19.0032 - mae: 19.4951 - learning_rate: 1.9953e-05
# Epoch 68/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 18.5243 - mae: 19.0169 - learning_rate: 2.2387e-05
# Epoch 69/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 18.1730 - mae: 18.6649 - learning_rate: 2.5119e-05
# Epoch 70/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 19.4882 - mae: 19.9812 - learning_rate: 2.8184e-05
# Epoch 71/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 20.6887 - mae: 21.1808 - learning_rate: 3.1623e-05
# Epoch 72/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 21.7611 - mae: 22.2564 - learning_rate: 3.5481e-05
# Epoch 73/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 18.3071 - mae: 18.8009 - learning_rate: 3.9811e-05
# Epoch 74/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.9650 - mae: 18.4577 - learning_rate: 4.4668e-05
# Epoch 75/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 20.0865 - mae: 20.5806 - learning_rate: 5.0119e-05
# Epoch 76/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.3842 - mae: 17.8758 - learning_rate: 5.6234e-05
# Epoch 77/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 17.8577 - mae: 18.3499 - learning_rate: 6.3096e-05
# Epoch 78/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 22.0873 - mae: 22.5818 - learning_rate: 7.0795e-05
# Epoch 79/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 22.4298 - mae: 22.9229 - learning_rate: 7.9433e-05
# Epoch 80/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 19.4409 - mae: 19.9337 - learning_rate: 8.9125e-05
# Epoch 81/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 18.3941 - mae: 18.8878 - learning_rate: 1.0000e-04
# Epoch 82/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 20.4390 - mae: 20.9341 - learning_rate: 1.1220e-04
# Epoch 83/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 22.9483 - mae: 23.4430 - learning_rate: 1.2589e-04
# Epoch 84/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 24.1496 - mae: 24.6442 - learning_rate: 1.4125e-04
# Epoch 85/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 22.2332 - mae: 22.7279 - learning_rate: 1.5849e-04
# Epoch 86/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 19.1660 - mae: 19.6591 - learning_rate: 1.7783e-04
# Epoch 87/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 25.7041 - mae: 26.1993 - learning_rate: 1.9953e-04
# Epoch 88/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 26.0357 - mae: 26.5323 - learning_rate: 2.2387e-04
# Epoch 89/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 30.3619 - mae: 30.8576 - learning_rate: 2.5119e-04
# Epoch 90/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 31.0123 - mae: 31.5079 - learning_rate: 2.8184e-04
# Epoch 91/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 38.4315 - mae: 38.9286 - learning_rate: 3.1623e-04
# Epoch 92/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 28.7740 - mae: 29.2712 - learning_rate: 3.5481e-04
# Epoch 93/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 31.0111 - mae: 31.5067 - learning_rate: 3.9811e-04
# Epoch 94/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 46ms/step - loss: 34.4050 - mae: 34.9020 - learning_rate: 4.4668e-04
# Epoch 95/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 37.1248 - mae: 37.6215 - learning_rate: 5.0119e-04
# Epoch 96/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 43.3696 - mae: 43.8665 - learning_rate: 5.6234e-04
# Epoch 97/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 50.5346 - mae: 51.0328 - learning_rate: 6.3096e-04
# Epoch 98/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 50.8639 - mae: 51.3615 - learning_rate: 7.0795e-04
# Epoch 99/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 46.4693 - mae: 46.9669 - learning_rate: 7.9433e-04
# Epoch 100/100
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 45.8278 - mae: 46.3257 - learning_rate: 8.9125e-04

# %%
  # Learning rates used above
lrs = 1e-8 * (10**(np.arange(epochs)/20))
lrs
# Out:
# array([1.00000000e-08, 1.12201845e-08, 1.25892541e-08, 1.41253754e-08,
#        1.58489319e-08, 1.77827941e-08, 1.99526231e-08, 2.23872114e-08,
#        2.51188643e-08, 2.81838293e-08, 3.16227766e-08, 3.54813389e-08,
#        3.98107171e-08, 4.46683592e-08, 5.01187234e-08, 5.62341325e-08,
#        6.30957344e-08, 7.07945784e-08, 7.94328235e-08, 8.91250938e-08,
#        1.00000000e-07, 1.12201845e-07, 1.25892541e-07, 1.41253754e-07,
#        1.58489319e-07, 1.77827941e-07, 1.99526231e-07, 2.23872114e-07,
#        2.51188643e-07, 2.81838293e-07, 3.16227766e-07, 3.54813389e-07,
#        3.98107171e-07, 4.46683592e-07, 5.01187234e-07, 5.62341325e-07,
#        6.30957344e-07, 7.07945784e-07, 7.94328235e-07, 8.91250938e-07,
#        1.00000000e-06, 1.12201845e-06, 1.25892541e-06, 1.41253754e-06,
#        1.58489319e-06, 1.77827941e-06, 1.99526231e-06, 2.23872114e-06,
#        2.51188643e-06, 2.81838293e-06, 3.16227766e-06, 3.54813389e-06,
#        3.98107171e-06, 4.46683592e-06, 5.01187234e-06, 5.62341325e-06,
#        6.30957344e-06, 7.07945784e-06, 7.94328235e-06, 8.91250938e-06,
#        1.00000000e-05, 1.12201845e-05, 1.25892541e-05, 1.41253754e-05,
#        1.58489319e-05, 1.77827941e-05, 1.99526231e-05, 2.23872114e-05,
#        2.51188643e-05, 2.81838293e-05, 3.16227766e-05, 3.54813389e-05,
#        3.98107171e-05, 4.46683592e-05, 5.01187234e-05, 5.62341325e-05,
#        6.30957344e-05, 7.07945784e-05, 7.94328235e-05, 8.91250938e-05,
#        1.00000000e-04, 1.12201845e-04, 1.25892541e-04, 1.41253754e-04,
#        1.58489319e-04, 1.77827941e-04, 1.99526231e-04, 2.23872114e-04,
#        2.51188643e-04, 2.81838293e-04, 3.16227766e-04, 3.54813389e-04,
#        3.98107171e-04, 4.46683592e-04, 5.01187234e-04, 5.62341325e-04,
#        6.30957344e-04, 7.07945784e-04, 7.94328235e-04, 8.91250938e-04])

# %%
# Fetch the optimum learning rate
min_loss = min(history.history['loss'])
idx_min_loss = history.history['loss'].index(min_loss)
opt_lr = lrs[idx_min_loss]
first = str(round(float(str(opt_lr).split('e')[0])))
second = str(opt_lr).split('e')[-1]
final = [first, second]
x = "e".join(final)
x = float(x)
print(f"Optimal Learning Rate was --> {x}.")
# Out:
# Optimal Learning Rate was --> 3e-06.

# %%
# Plot the output of Losses vs Learning Rates
fig = plt.figure(figsize=(15, 6))
plt.semilogx(lrs, history.history["loss"]) # Learning rates are increasing exponentially and hence for an omptimal sized plot we use semilogx plot
plt.grid(True, ls="--")
plt.plot(opt_lr,min_loss, color = 'r', marker = 'x', markersize = 7)
plt.title(f"Looking for Optimum Learning Rate", color = 'm', fontsize = 15)
plt.ylabel("Losses", fontsize = 13, color = 'g')
plt.xlabel("Learining Rates", fontsize = 13, color = 'g')
plt.annotate(f"lr = {x}", (opt_lr,min_loss+2), (opt_lr+0.05e-5, min_loss+15), arrowprops = dict(facecolor ='k', width = 2, headwidth = 8), fontsize = 12)
plt.show()

# %% [markdown]
# # Training the model with the Optimal Learning Rate

# %%
# Using the same steps to build the model but now with the optimal learning rate to train it
tf.keras.backend.clear_session()
tf.random.set_seed(42)
np.random.seed(42)

model = tf.keras.models.Sequential([
  tf.keras.layers.Conv1D(filters=132, kernel_size=4,strides=1, padding="causal", activation="relu",input_shape=[None, 1]),
  tf.keras.layers.LSTM(256, return_sequences=True),
  tf.keras.layers.LSTM(132, return_sequences=False),
  tf.keras.layers.Dense(80, activation="relu"),
  tf.keras.layers.Dense(10, activation="relu"),
  tf.keras.layers.Dense(1),
  tf.keras.layers.Lambda(lambda x: x * 400)
])

optimizer = tf.keras.optimizers.SGD(learning_rate=opt_lr, momentum=momentum_sgd)
model.compile(loss=tf.keras.losses.Huber(delta),
              optimizer=optimizer,
              metrics=["mae"])
history = model.fit(train_set,epochs=train_epochs)
# Out:
# Epoch 1/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 31.8597 - mae: 32.3564
# Epoch 2/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 20.2850 - mae: 20.7805
# Epoch 3/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 18.9678 - mae: 19.4616
# Epoch 4/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 18.3542 - mae: 18.8488
# Epoch 5/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 18.0046 - mae: 18.4987
# Epoch 6/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.1704 - mae: 17.6603
# Epoch 7/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 18.0121 - mae: 18.5033
# Epoch 8/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 19.5656 - mae: 20.0586
# Epoch 9/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 18.1302 - mae: 18.6219
# Epoch 10/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 46ms/step - loss: 17.6928 - mae: 18.1856
# Epoch 11/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 17.2557 - mae: 17.7461
# Epoch 12/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 17.8509 - mae: 18.3422
# Epoch 13/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.6327 - mae: 18.1249
# Epoch 14/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.3110 - mae: 17.8034
# Epoch 15/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.1002 - mae: 17.5907
# Epoch 16/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 18.0475 - mae: 18.5400
# Epoch 17/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 16.7864 - mae: 17.2754
# Epoch 18/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 17.2287 - mae: 17.7223
# Epoch 19/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.2570 - mae: 17.7481
# Epoch 20/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.6666 - mae: 18.1571
# Epoch 21/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 17.7130 - mae: 18.2056
# Epoch 22/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 16.8649 - mae: 17.3551
# Epoch 23/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 17.0632 - mae: 17.5531
# Epoch 24/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.0828 - mae: 17.5769
# Epoch 25/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.2939 - mae: 17.7840
# Epoch 26/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.2357 - mae: 17.7260
# Epoch 27/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.5348 - mae: 17.0243
# Epoch 28/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.7939 - mae: 18.2881
# Epoch 29/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.0359 - mae: 17.5275
# Epoch 30/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.9665 - mae: 17.4562
# Epoch 31/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 17.1888 - mae: 17.6800
# Epoch 32/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 17.2787 - mae: 17.7687
# Epoch 33/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 44ms/step - loss: 17.6187 - mae: 18.1113
# Epoch 34/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 17.1180 - mae: 17.6083
# Epoch 35/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 16.8192 - mae: 17.3094
# Epoch 36/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.8837 - mae: 18.3755
# Epoch 37/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.0043 - mae: 17.4947
# Epoch 38/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.8528 - mae: 17.3421
# Epoch 39/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.8433 - mae: 17.3347
# Epoch 40/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 17.0765 - mae: 17.5673
# Epoch 41/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.6072 - mae: 18.1004
# Epoch 42/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.1631 - mae: 17.6554
# Epoch 43/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 17.2805 - mae: 17.7724
# Epoch 44/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.5925 - mae: 18.0830
# Epoch 45/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 16.9169 - mae: 17.4075
# Epoch 46/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 16.6575 - mae: 17.1484
# Epoch 47/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 16.3695 - mae: 16.8598
# Epoch 48/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 16.3192 - mae: 16.8110
# Epoch 49/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.4629 - mae: 16.9524
# Epoch 50/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.1556 - mae: 16.6448
# Epoch 51/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.6518 - mae: 17.1417
# Epoch 52/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.3225 - mae: 16.8113
# Epoch 53/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.2292 - mae: 17.7198
# Epoch 54/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.0966 - mae: 16.5863
# Epoch 55/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 16.3406 - mae: 16.8320
# Epoch 56/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.6649 - mae: 17.1543
# Epoch 57/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.7497 - mae: 17.2392
# Epoch 58/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.5719 - mae: 17.0611
# Epoch 59/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.2700 - mae: 16.7609
# Epoch 60/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.9212 - mae: 16.4123
# Epoch 61/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 16.1999 - mae: 16.6899
# Epoch 62/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 17.7100 - mae: 18.2003
# Epoch 63/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 16.4503 - mae: 16.9409
# Epoch 64/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.2764 - mae: 16.7664
# Epoch 65/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 16.6687 - mae: 17.1604
# Epoch 66/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 17.3092 - mae: 17.7986
# Epoch 67/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.0341 - mae: 16.5262
# Epoch 68/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.9398 - mae: 16.4293
# Epoch 69/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.9943 - mae: 16.4838
# Epoch 70/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.0288 - mae: 16.5187
# Epoch 71/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.5116 - mae: 17.0006
# Epoch 72/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.2799 - mae: 16.7693
# Epoch 73/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 50ms/step - loss: 16.2189 - mae: 16.7092
# Epoch 74/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 16.4596 - mae: 16.9492
# Epoch 75/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 17.1704 - mae: 17.6632
# Epoch 76/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 17.0707 - mae: 17.5633
# Epoch 77/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.0906 - mae: 16.5817
# Epoch 78/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 16.0906 - mae: 16.5801
# Epoch 79/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.0012 - mae: 16.4895
# Epoch 80/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.7478 - mae: 16.2399
# Epoch 81/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 16.4315 - mae: 16.9207
# Epoch 82/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.7990 - mae: 17.2910
# Epoch 83/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 16.1538 - mae: 16.6441
# Epoch 84/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 54ms/step - loss: 16.1175 - mae: 16.6076
# Epoch 85/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.5874 - mae: 17.0784
# Epoch 86/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.3782 - mae: 16.8680
# Epoch 87/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.1142 - mae: 16.6036
# Epoch 88/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.5808 - mae: 16.0641
# Epoch 89/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.1869 - mae: 16.6775
# Epoch 90/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.4190 - mae: 16.9076
# Epoch 91/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.3549 - mae: 16.8433
# Epoch 92/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.6489 - mae: 17.1424
# Epoch 93/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 16.3814 - mae: 16.8705
# Epoch 94/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.0137 - mae: 16.5040
# Epoch 95/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.8732 - mae: 16.3610
# Epoch 96/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 51ms/step - loss: 16.3459 - mae: 16.8378
# Epoch 97/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 25ms/step - loss: 16.7896 - mae: 17.2806
# Epoch 98/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.4018 - mae: 16.8938
# Epoch 99/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 16.2055 - mae: 16.6959
# Epoch 100/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.6664 - mae: 16.1560
# Epoch 101/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.1689 - mae: 16.6579
# Epoch 102/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.2111 - mae: 16.7020
# Epoch 103/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.8790 - mae: 16.3691
# Epoch 104/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.4555 - mae: 16.9455
# Epoch 105/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.9427 - mae: 16.4320
# Epoch 106/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.5526 - mae: 17.0424
# Epoch 107/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.0680 - mae: 16.5578
# Epoch 108/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 15.8035 - mae: 16.2908
# Epoch 109/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 47ms/step - loss: 15.6721 - mae: 16.1596
# Epoch 110/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 15.9549 - mae: 16.4483
# Epoch 111/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.7444 - mae: 16.2338
# Epoch 112/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 16.2779 - mae: 16.7684
# Epoch 113/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.1765 - mae: 16.6676
# Epoch 114/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 15.8919 - mae: 16.3804
# Epoch 115/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.0649 - mae: 16.5547
# Epoch 116/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.7941 - mae: 16.2811
# Epoch 117/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 29ms/step - loss: 16.2164 - mae: 16.7055
# Epoch 118/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.5492 - mae: 17.0385
# Epoch 119/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.1117 - mae: 16.6011
# Epoch 120/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.8012 - mae: 16.2901
# Epoch 121/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 15.7993 - mae: 16.2890
# Epoch 122/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 48ms/step - loss: 16.2606 - mae: 16.7501
# Epoch 123/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 28ms/step - loss: 16.0474 - mae: 16.5390
# Epoch 124/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.8935 - mae: 16.3840
# Epoch 125/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.9928 - mae: 16.4810
# Epoch 126/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.1519 - mae: 16.6412
# Epoch 127/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.9623 - mae: 16.4499
# Epoch 128/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.6378 - mae: 16.1290
# Epoch 129/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.6562 - mae: 16.1476
# Epoch 130/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 15.8956 - mae: 16.3866
# Epoch 131/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.2900 - mae: 15.7801
# Epoch 132/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 15.7089 - mae: 16.1973
# Epoch 133/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 48ms/step - loss: 15.8654 - mae: 16.3547
# Epoch 134/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 16.1226 - mae: 16.6110
# Epoch 135/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 15.3003 - mae: 15.7892
# Epoch 136/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.5012 - mae: 15.9898
# Epoch 137/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.7295 - mae: 16.2178
# Epoch 138/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.0920 - mae: 16.5833
# Epoch 139/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 15.4793 - mae: 15.9666
# Epoch 140/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.8719 - mae: 16.3613
# Epoch 141/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 15.6402 - mae: 16.1301
# Epoch 142/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 15.3166 - mae: 15.8040
# Epoch 143/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - loss: 15.4491 - mae: 15.9381
# Epoch 144/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.2641 - mae: 15.7523
# Epoch 145/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 15.5507 - mae: 16.0386
# Epoch 146/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.0387 - mae: 16.5297
# Epoch 147/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.7460 - mae: 16.2333
# Epoch 148/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 40ms/step - loss: 15.3328 - mae: 15.8210
# Epoch 149/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 49ms/step - loss: 15.9383 - mae: 16.4251
# Epoch 150/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 55ms/step - loss: 15.8227 - mae: 16.3121
# Epoch 151/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.5599 - mae: 16.0482
# Epoch 152/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.4736 - mae: 15.9629
# Epoch 153/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.9405 - mae: 16.4303
# Epoch 154/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.8697 - mae: 16.3575
# Epoch 155/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.2969 - mae: 15.7852
# Epoch 156/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.9024 - mae: 16.3937
# Epoch 157/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.6352 - mae: 16.1255
# Epoch 158/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.6949 - mae: 16.1822
# Epoch 159/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.4020 - mae: 15.8908
# Epoch 160/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.7743 - mae: 16.2630
# Epoch 161/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 40ms/step - loss: 15.5406 - mae: 16.0288
# Epoch 162/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 15.3366 - mae: 15.8287
# Epoch 163/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 15.3922 - mae: 15.8834
# Epoch 164/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 16.0606 - mae: 16.5519
# Epoch 165/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.1168 - mae: 16.6079
# Epoch 166/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.3301 - mae: 15.8182
# Epoch 167/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.8733 - mae: 16.3621
# Epoch 168/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 15.4805 - mae: 15.9670
# Epoch 169/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.5100 - mae: 16.0012
# Epoch 170/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.1767 - mae: 15.6664
# Epoch 171/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.3258 - mae: 15.8155
# Epoch 172/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.0484 - mae: 15.5368
# Epoch 173/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.4622 - mae: 15.9511
# Epoch 174/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.5499 - mae: 16.0411
# Epoch 175/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 15.2451 - mae: 15.7359
# Epoch 176/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - loss: 15.6048 - mae: 16.0908
# Epoch 177/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 52ms/step - loss: 15.9452 - mae: 16.4344
# Epoch 178/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 26ms/step - loss: 15.4435 - mae: 15.9337
# Epoch 179/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.4985 - mae: 15.9859
# Epoch 180/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.2874 - mae: 15.7753
# Epoch 181/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.3736 - mae: 15.8641
# Epoch 182/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.7890 - mae: 16.2754
# Epoch 183/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.1020 - mae: 16.5921
# Epoch 184/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.6064 - mae: 16.0957
# Epoch 185/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 15.9832 - mae: 16.4735
# Epoch 186/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.4544 - mae: 15.9388
# Epoch 187/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 54ms/step - loss: 16.3216 - mae: 16.8134
# Epoch 188/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 27ms/step - loss: 16.2507 - mae: 16.7419
# Epoch 189/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.3049 - mae: 16.7970
# Epoch 190/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.6890 - mae: 16.1786
# Epoch 191/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 16.1640 - mae: 16.6529
# Epoch 192/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.5206 - mae: 16.0091
# Epoch 193/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.1336 - mae: 15.6230
# Epoch 194/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 27ms/step - loss: 15.1504 - mae: 15.6373
# Epoch 195/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 15.8483 - mae: 16.3393
# Epoch 196/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 26ms/step - loss: 16.5029 - mae: 16.9944
# Epoch 197/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - loss: 15.3644 - mae: 15.8541
# Epoch 198/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 2s 47ms/step - loss: 15.5334 - mae: 16.0225
# Epoch 199/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 15.1728 - mae: 15.6620
# Epoch 200/200
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - loss: 15.4094 - mae: 15.8983

# %%
# Fetch the MAE and Huber Loss from the history
mae=history.history['mae']
loss=history.history['loss']

# Plot MAE and Huber Loss
fig = plt.figure(figsize=(15, 6))
plt.plot(mae, 'r')
plt.plot(loss, 'b')
plt.title('MAE and Loss')
plt.xlabel("Epochs")
plt.legend(["MAE", "Loss"])

# %%
# Call the model_forecast here and display the plots of validation and prediction
rnn_forecast = model_forecast(model, series[:, np.newaxis], window_size)
rnn_forecast = rnn_forecast[split_time - window_size:-1, 0]  # rnn_forecast[-328:-1, 0]

# Plots
plt.figure(figsize=(15, 6))
plt.plot(time_valid, x_valid)
plt.plot(time_valid, rnn_forecast)
plt.title("")
plt.legend(["Validation Data", "Predicted Data"])
plt.show()
# Out:
# 23/23 ━━━━━━━━━━━━━━━━━━━━ 2s 59ms/step

# %%
# Validation MAE
val_mae=tf.keras.metrics.mae(x_valid, rnn_forecast).numpy()
print(f"MAE on the validation data:- {val_mae}")
# Out:
# MAE on the validation data:- 12.371964454650879
